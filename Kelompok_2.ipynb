# %% [markdown]
# <a href="https://colab.research.google.com/github/HaidarHalwi/TheSelectClothing/blob/main/Kelompok_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variabel biasa
variabel_biasa = 10+10

print(variabel_biasa)
# Out:
# 20

# %%
# Variabel array
variabel_array = [1,2,3,4]

print(variabel_array)
# Out:
# [1, 2, 3, 4]

# %%
# Variabel dictionary
variabel_dictionary = {
    "nama": "oskhar",
    "nilai": [1,2,3,4],
    "kuliah": "uwin"
}
print(variabel_dictionary)
print(variabel_dictionary["nama"])
# Out:
# {'nama': 'oskhar', 'nilai': [1, 2, 3, 4], 'kuliah': 'uwin'}
# oskhar

# %%
import pandas as pd
data = {
    "ewogs": [1.2,2,3,4],
    "tanjung": [4.0,3,2,1]
}

show = pd.DataFrame(data)
show.min()
# Out:
# ewogs      1.2
# tanjung    1.0
# dtype: float64
